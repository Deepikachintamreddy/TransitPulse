# %% [markdown]
# # TransitPulse — GPU Performance Benchmark Race on Colab T4
# This notebook installs RAPIDS `cudf.pandas`, generates synthetic transit pings at 1M, 25M, and 150M row scales, and runs the identical processing pipeline on both CPU (pure pandas) and GPU (cudf.pandas) to measure speedups.

# %% [markdown]
# ### 1. Install RAPIDS cudf.pandas and requirements

# %%
# Install RAPIDS cudf (compatible with Colab T4 GPU)
# !pip install -q git+https://github.com/rapidsai/cudf.git
# !pip install pyarrow duckdb fastapi uvicorn matplotlib google-genai

# %% [markdown]
# ### 2. Download/Clone repository code
# *(Or upload config.py, generate_pings.py, pipeline.py, and benchmark.py directly)*

# %%
# Run the benchmark race live across all scales!
# This will output the timings and speedup_chart.png
# !python benchmark.py --run-all

# %% [markdown]
# ### 3. Display the GPU vs CPU Speedup Chart

# %%
from IPython.display import Image
Image('data/speedup_chart.png')
